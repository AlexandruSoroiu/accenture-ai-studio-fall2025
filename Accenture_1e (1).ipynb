# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_fake = pd.read_csv('Fake.csv')
df_real = pd.read_csv('True.csv')

# %%
df_fake.tail(10)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
df_real.tail(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
f_null_values = df_fake.isnull().sum()
print(f_null_values)
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
r_null_values = df_real.isnull().sum()
print(r_null_values)
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df_fake.shape
# Out:
# (23481, 4)

# %%
df_real.shape
# Out:
# (21417, 4)

# %%
fake_df = df_fake.sample(n=20, random_state=None) 

print(fake_df)
# Out:
#                                                    title  \
# 9015    What Twitter Just Did To Right-Wingers Makes ...
# 15372  IS HILLARY GOING DOWN IN FLAMES? Latest Poll S...
# 18345  KELLYANNE CONWAY Slaps Down Rabid CNN Host Chr...
# 15984  FACTORY WORKER RIPS INTO Speaker Paul Ryan on ...
# 1574    In 2011, Stephen Colbert Gave Us A Futuristic...
# 1628    WATCH: Former Reagan Adviser Is Totally DISGU...
# 3244    Evan McMullin GOES THERE, Says What No Republ...
# 18488  UNHINGED PELOSI: It’s “Outrageous” That Republ...
# 2912    Trump Said The Media Lied About His PATHETIC ...
# 11788  JUDGE JEANINE: LIKE IT OR NOT…Laws Are Being E...
# 15555  [VIDEO] SHOCKING CONSEQUENCES OF OPEN IMMIGRAT...
# 12907  FLASHBACK: MALCOLM X On Blacks Who Keep Voting...
# 120     Trump Jr. Goes Full Dumba** On Twitter By Pro...
# 16893  NEW POLICY: TSA Can Now Force You To Go Throug...
# 3164    Sarah Palin Gets OWNED For Sucking Up To Juli...
# ...

# %%
real_df = df_real.sample(n=20, random_state=None) 

print(real_df)
# Out:
#                                                    title  \
# 20152  Spain calls Catalan mayors for questioning on ...
# 7393   Republicans hold on to state legislative edge ...
# 20362  With 7.4 million without power, utility worker...
# 1853            Trump, his party: an American odd couple
# 19933  Italy's 5-Star launches vote for leader, Di Ma...
# 16702  Despite apology, Indonesia asks why U.S. block...
# 20517  Pope, in Medellin, recalls 'painful memory' of...
# 6347   Trump scorns probe into FBI pre-election handl...
# 20243  Brazil's top court approves new graft probe of...
# 8758   FBI, Homeland Security chiefs preparing for vi...
# 1613   Republican Senator Collins 'leaning against' n...
# 9632   Chagrined anti-Trump Republicans seek to recru...
# 9470   Trump taps adviser Manafort to be campaign cha...
# 3977   Congress to fund more detention beds despite d...
# 10011  Poll: Trump extends his lead among Republicans...
# ...

# %%
df_real['subject'].value_counts()
# Out:
# subject
# politicsNews    11272
# worldnews       10145
# Name: count, dtype: int64

# %%
df_fake['subject'].value_counts()
# Out:
# subject
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
df_real['title'].str.len().hist()
# Out:
# <Axes: >

# %%
df_fake['title'].str.len().hist()
# Out:
# <Axes: >

# %%
real_df['text'].str.len().hist()
# Out:
# <Axes: >

# %%
df_fake['text'].str.len().hist()
# Out:
# <Axes: >

# %% [markdown]
# Checking for "Reuters" usage

# %%
row_fake_reuter = df_fake['text'].str.contains("Reuters", case=False, na=False)

print(f"Number of rows containing 'Reuters': {row_fake_reuter.sum()}")

df_fake['text'].shape
# Out:
# Number of rows containing 'Reuters': 322
# (23481,)

# %%
count_reuters_text_fake = df_fake['text'].str.count("Reuters").sum()

print(f"The word 'Reuters' appears {int(count_reuters_text_fake)} times in the text column.")

df_fake['text'].shape
# Out:
# The word 'Reuters' appears 454 times in the text column.
# (23481,)

# %%
count_reuters_text = df_real['text'].str.count("Reuters").sum()

print(f"The word 'Reuters' appears {int(count_reuters_text)} times in the text column.")

df_real['text'].shape
# Out:
# The word 'Reuters' appears 28909 times in the text column.
# (21417,)

# %%
row_reuter = df_real['text'].str.contains("Reuters", case=False, na=False)

print(f"Number of rows containing 'Reuters': {row_reuter.sum()}")
# Out:
# Number of rows containing 'Reuters': 21378

# %%
without_reuter_df = df_real[df_real['text'].str.contains('Reuters') == False]
without_reuter_df
# Out:
#                                                    title  \
# 103    Democratic U.S. senator seeks audit of EPA chi...
# 427    Factbox: Republicans to watch in U.S. Senate t...
# 1141   GAO opens door for Congress to review leverage...
# 3488   White House unveils list of ex-lobbyists grant...
# 4358   Factbox: Trump Supreme Court appointee to affe...
# 5363   Trump's defense chief visits UAE in first Midd...
# 5784   Trump Supreme Court nominee Gorsuch seen in th...
# 5821        Kushner divests equity in major NYC property
# 6823   Commentary: Trump can't fight Islamic State wi...
# 7365   Tough reality check for Trump's pledge of bett...
# 7922   Commentary: Manic or evasive - these veep guys...
# 8195        Factbox: Why the Zika virus is causing alarm
# 8247     Obama drinks coconut water to cool down in Laos
# 8481        Factbox: Why the Zika virus is causing alarm
# 8505        Factbox: Why the Zika virus is causing alarm
# ...

# %% [markdown]
# Found a random empty cell, opened it up un excel and double checked here:

# %%
df_real[8970:8971]
# Out:
#                                title text       subject            date
# 8970  Graphic: Supreme Court roundup       politicsNews  June 16, 2016

# %%
df_real['text'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Checking for contraction usage

# %%
count_contractions_text = df_real['text'].str.count("'").sum()

print(f"A contraction appears {int(count_contractions_text)} times in the text column.")
# Out:
# A contraction appears 435 times in the text column.

# %%
count_contractions_title = df_real['title'].str.count("'").sum()

print(f"A contraction appears {int(count_contractions_title)} times in the title column.")
# Out:
# A contraction appears 9372 times in the title column.

# %%
count_contractions_ftext = df_fake['text'].str.count("'").sum()

print(f"A contraction appears {int(count_contractions_ftext)} times in the text column.")
# Out:
# A contraction appears 5656 times in the text column.

# %%
count_contractions_ftitle = df_fake['title'].str.count("'").sum()

print(f"A contraction appears {int(count_contractions_ftitle)} times in the title column.")
# Out:
# A contraction appears 18 times in the title column.
