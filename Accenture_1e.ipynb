# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_fake = pd.read_csv('Fake.csv')
df_real = pd.read_csv('True.csv')

# %%
df_fake.tail(10)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
df_real.tail(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
f_null_values = df_fake.isnull().sum()
print(f_null_values)
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
r_null_values = df_real.isnull().sum()
print(r_null_values)
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df_fake.shape
# Out:
# (23481, 4)

# %%
df_real.shape
# Out:
# (21417, 4)

# %%
fake_df = df_fake.sample(n=20, random_state=None) 

print(fake_df)
# Out:
#                                                    title  \
# 3224    Republican Strategist Calls Out Trump’s ‘Ball...
# 774     Carrier Employee Speaks Out On Trump: ‘He Ble...
# 4325    Florida Governor Uses Hurricane Matthew As Ex...
# 18379  WHY ISN’T MEDIA ASKING IF NYPD Cop-Killer and ...
# 1788    China Warns Trump: Provoke North Korea And ‘P...
# 9844   Great Answer! Sean Spicer Asked To Name CNN Re...
# 22019  Liberal Imperium: Quigley’s Anglo-American Est...
# 17114  WHY DID THE UN HAVE A PRO-GUN CONTROL MEETING ...
# 14993  Why This New Book By Lib Writer And Radio Host...
# 10182  UPDATE ON 9/11 MEMORIAL Banned for “Triggering...
# 20081  DON’T EXPECT GOVERNMENT Or Black Lives Matter ...
# 5560    Trump’s Son-In-Law OBLITERATED By His Jewish ...
# 13502  BRUTALLY HONEST BILLBOARD Turns Heads In State...
# 10832  OUTRAGE! Student Threatens Violence Against Tr...
# 727     Boy Scouts Forced To Apologize On Trump’s Behalf
# ...

# %%
real_df = df_real.sample(n=20, random_state=None) 

print(real_df)
# Out:
#                                                    title  \
# 9267   Which ‘La Raza’? Trump comments cause confusio...
# 4965   Tillerson's email alias was prompted by busine...
# 813    Special Counsel Mueller has enough evidence to...
# 19431  Power crews scramble to Puerto Rico after Mari...
# 17382  Catalan leader must drop independence by Thurs...
# 9749   U.S. says working to cut off North Korean remi...
# 10492  Obama to visit Patagonian tourist city Bariloc...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 10898   Supreme Court blocks Obama carbon emissions plan
# 9705   Cruz unleashes fury at Trump over Lee Harvey O...
# 19380  U.S. Navy carrier drills with Japanese navy am...
# 1151   Settlement proposed in North Carolina transgen...
# 10707  Senators say Republican consensus is no vote o...
# 18089  Swiss police say knife-wielding asylum seeker ...
# 7041   Trump faces dilemma as U.S. oil reels from rec...
# ...

# %%
real_df['subject'].unique()
# Out:
# array(['politicsNews', 'worldnews'], dtype=object)

# %%
fake_df['subject'].unique()
# Out:
# array(['News', 'left-news', 'politics', 'US_News', 'Government News'],
#       dtype=object)

# %%
real_df['title'].str.len().hist()
# Out:
# <Axes: >

# %%
fake_df['title'].str.len().hist()
# Out:
# <Axes: >

# %%
real_df['text'].str.len().hist()
# Out:
# <Axes: >

# %%
fake_df['text'].str.len().hist()
# Out:
# <Axes: >

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subjet'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 real_df['subjet'].value_counts()
#
# ...
